# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehaa08/EDA-PROJECT/blob/main/HealthCare_Eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# Dataset Information:
#
# Each column provides specific information about the patient, their admission, and the healthcare services provided, making this dataset suitable for various data analysis and modeling tasks in the healthcare domain. Here's a brief explanation of each column in the dataset -
#
# Name: This column represents the name of the patient associated with the healthcare record.
#
# Age: The age of the patient at the time of admission, expressed in years.
#
# Gender: Indicates the gender of the patient, either "Male" or "Female."
#
# Blood Type: The patient's blood type, which can be one of the common blood types (e.g., "A+", "O-", etc.).
#
# Medical Condition: This column specifies the primary medical condition or diagnosis associated with the patient, such as "Diabetes," "Hypertension," "Asthma," and more.
#
# Date of Admission: The date on which the patient was admitted to the healthcare facility.
#
# Doctor: The name of the doctor responsible for the patient's care during their admission.
#
# Hospital: Identifies the healthcare facility or hospital where the patient was admitted.
#
# Insurance Provider: This column indicates the patient's insurance provider, which can be one of several options, including "Aetna," "Blue Cross," "Cigna," "UnitedHealthcare," and "Medicare."
#
# Billing Amount: The amount of money billed for the patient's healthcare services during their admission. This is expressed as a floating-point number.
#
# Room Number: The room number where the patient was accommodated during their admission.
#
# Admission Type: Specifies the type of admission, which can be "Emergency," "Elective," or "Urgent," reflecting the circumstances of the admission.
#
# Discharge Date: The date on which the patient was discharged from the healthcare facility, based on the admission date and a random number of days within a realistic range.
#
# Medication: Identifies a medication prescribed or administered to the patient during their admission. Examples include "Aspirin," "Ibuprofen," "Penicillin," "Paracetamol," and "Lipitor."
#
# Test Results: Describes the results of a medical test conducted during the patient's admission. Possible values include "Normal," "Abnormal," or "Inconclusive," indicating the outcome of the test.

# %% [markdown]
# ##Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.offline as pyo
import plotly.io as pio
import sklearn
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##Importing Dataset

# %%
data = pd.read_csv("healthcare_dataset.csv")
data.head().T
# Out:
#                                    0                          1             2  \
# Name                 Tiffany Ramirez                Ruben Burns     Chad Byrd
# Age                               81                         35            61
# Gender                        Female                       Male          Male
# Blood Type                        O-                         O+            B-
# Medical Condition           Diabetes                     Asthma       Obesity
# Date of Admission         2022-11-17                 2023-06-01    2019-01-09
# Doctor                Patrick Parker              Diane Jackson    Paul Baker
# Hospital            Wallace-Hamilton  Burke, Griffin and Cooper    Walton LLC
# Insurance Provider          Medicare           UnitedHealthcare      Medicare
# Billing Amount          37490.983364               47304.064845  36874.896997
# Room Number                      146                        404           292
# ...

# %% [markdown]
# ##Inspecting data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %% [markdown]
# ##Check whether data is available or not

# %%
data.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# ##Check the shape and columns

# %%
data.shape
# Out:
# (10000, 15)

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %% [markdown]
# ##Summmary of the dataset

# %%
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %% [markdown]
# ##Observation from above
#
#
# - The dataset consists of 10,000 observations for each variable.
# - **First Variable**:
#   - Mean: 51.45
#   - Standard Deviation: 19.59
#   - Range: 18.00 to 85.00
# - **Second Variable**:
#   - Mean: 25,516.81
#   - Standard Deviation: 14,067.29
#   - Range: 1,000.18 to 49,995.90
# - **Third Variable**:
#   - Mean: 300.08
#   - Standard Deviation: 115.81
#   - Range: 101.00 to 500.00

# %% [markdown]
# ##checking if there are any duplicate records in dataset

# %%
data.duplicated().sum()
# Out:
# 0

# %%
for i in data.describe(include='object'):
    print('Unique values in ',i,'are : ')
    print(data[i].value_counts())
    print('-'*50)
# Out:
# Unique values in  Name are :
# Name
# Michael Johnson        7
# James Johnson          6
# Michael Miller         4
# Michelle Williams      4
# Scott Smith            4
#                       ..
# Sharon Rose            1
# Stephanie Knox         1
# Anthony Jones          1
# Melissa Perkins DVM    1
# Eric King              1
# Name: count, Length: 9378, dtype: int64
# --------------------------------------------------
# Unique values in  Gender are :
# Gender
# Female    5075
# Male      4925
# Name: count, dtype: int64
# --------------------------------------------------
# Unique values in  Blood Type are :
# Blood Type
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: count, dtype: int64
# --------------------------------------------------
# Unique values in  Medical Condition are :
# Medical Condition
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# ...

# %% [markdown]
# #Observations from above
#
#
# - There are 9,378 unique names, with Michael Johnson being the most frequent (7 occurrences) and James Johnson following (6 occurrences).
# - The dataset includes 5,075 females and 4,925 males.
# - Blood types are distributed as follows: AB- (1,275), AB+ (1,258), B- (1,252), O+ (1,248), O- (1,244), B+ (1,244), A+ (1,241), and A- (1,238).
# - The most common medical conditions are Asthma (1,708 cases), Cancer (1,703 cases), Hypertension (1,688 cases), Arthritis (1,650 cases), Obesity (1,628 cases), and Diabetes (1,623 cases).
# - The dates of admission are varied, with 2019-04-12 and 2022-04-27 each occurring 15 times, and a total of 1,815 unique admission dates.
# - There are 9,416 unique doctors, with Michael Johnson being the most frequent (7 occurrences) and Robert Brown (5 occurrences).
# - The most frequent hospitals are Smith PLC (19 occurrences) and Smith and Sons (17 occurrences), among 8,639 unique hospitals.
# - Insurance providers are distributed as follows: Cigna (2,040), Blue Cross (2,032), Aetna (2,025), UnitedHealthcare (1,978), and Medicare (1,925).
# - Admission types are categorized as Urgent (3,391 cases), Emergency (3,367 cases), and Elective (3,242 cases).
# - Discharge dates vary, with 2021-11-28 and 2020-10-08 each occurring 14 times, and a total of 1,834 unique discharge dates.
# - The most common medications are Penicillin (2,079 cases), Lipitor (2,015 cases), Ibuprofen (1,976 cases), Aspirin (1,968 cases), and Paracetamol (1,962 cases).
# - Test results are categorized as Abnormal (3,456 cases), Inconclusive (3,277 cases), and Normal (3,267 cases).

# %% [markdown]
# ##EDA

# %% [markdown]
# ###Univariate Analysis

# %%
data.describe(exclude=['O'])
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
data.hist(bins=50, figsize=(12,8))
plt.show()

# %%
# categorical features

data.describe(include=['O'])
# Out:
#                    Name  Gender Blood Type Medical Condition           Doctor  \
# count             10000   10000      10000             10000            10000
# unique             9378       2          8                 6             9416
# top     Michael Johnson  Female        AB-            Asthma  Michael Johnson
# freq                  7    5075       1275              1708                7
#
#          Hospital Insurance Provider Admission Type  Medication Test Results
# count       10000              10000          10000       10000        10000
# unique       8639                  5              3           5            3
# top     Smith PLC              Cigna         Urgent  Penicillin     Abnormal
# freq           19               2040           3391        2079         3456

# %%
cols = ['Gender','Blood Type', 'Medical Condition',
        'Insurance Provider', 'Admission Type',
        'Medication', 'Test Results']

# %%
# Categorical Features
for i in cols:
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))  # Create a subplot with 2 columns
    fig.suptitle(f'** {i} **', fontsize=20)  # Set the title for the figure

    # Apply Seaborn style for the bar chart
    sns.set_theme(style="whitegrid")

    # Plot bar chart
    plt.subplot(1, 2, 1)  # Specify the subplot (1 row, 2 columns, first subplot)
    data[i].value_counts().plot(kind='bar', color=sns.color_palette("tab10"))
    plt.title(f'{i} Count')
    plt.xlabel(i)
    plt.ylabel('Count')

    # Apply Seaborn style for the pie chart
    sns.set_theme(style="whitegrid")

    # Plot pie chart
    plt.subplot(1, 2, 2)  # Specify the subplot (1 row, 2 columns, second subplot)
    data[i].value_counts().plot(kind='pie', autopct="%.2f%%", colors=sns.color_palette("tab10"))
    plt.title(f'{i} Distribution')
    plt.ylabel('')  # Hide the y-axis label for pie chart

    # Show the plot
    plt.show()

# %%
# Out:
# <div>                            <div id="4be317f6-b8b1-425e-b650-93e5cdbdc409" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4be317f6-b8b1-425e-b650-93e5cdbdc409")) {                    Plotly.newPlot(                        "4be317f6-b8b1-425e-b650-93e5cdbdc409",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eBilling Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Female","Male"],"xaxis":"x","y":[129333254.30684218,125834813.4705418],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"col
# ...
